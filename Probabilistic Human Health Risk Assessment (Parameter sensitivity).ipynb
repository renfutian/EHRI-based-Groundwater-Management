# %%
# 概率人体健康风险评估 (Probabilistic Human Health Risk Assessment)
import os
import pandas as pd
import numpy as np

# 计算 口服摄入 暴露剂量 (Calculate oral ingestion exposure dose)
def cal_add_oral_ingestion(C_i, IR, EF, ED, BW, AT):
    return (C_i/1000 * IR * EF * ED) / (BW * AT)

# 计算 吸入 暴露剂量 (Calculate inhalation exposure dose)
def cal_add_inhalation(C_i, DAIR, EF, ED, VF, BW, AT):
    return (C_i/1000 * DAIR * EF * ED * VF) / (BW * AT)

# 计算 皮肤接触 暴露剂量 (Calculate dermal contact exposure dose)
def cal_add_dermal(C_i, SA, F, PC, ET, EF, ED, BW, AT):
    return (C_i/1000 * SA * F * PC * ET * EF * ED) / (BW * AT) * 1e-3

# 计算 致癌风险 (Calculate cancer risk)
def cal_CR(add, SF):
    return add * SF

# 计算 非致癌风险 (Calculate non-cancer risk)
def cal_hq(add, RfD):
    RfD[RfD == 0] = np.nan  # RfD里有0 (RfD contains 0)
    return add / RfD


def write_csv(file_path='./write.csv', rowdata=[]):
    with open(file_path, 'a') as f:
        f.write(','.join([f"{data:.9f}" if isinstance(data, float) else str(data) for data in rowdata]))
        f.write('\n')

# %%
# 读取污染物参数 (Read pollutant parameters)
file_root_dir = os.path.dirname(os.path.realpath('__file__'))
file_path = os.path.join(file_root_dir, 'data', 'Pollutants toxicity.xlsx')
param_data = pd.read_excel(file_path, index_col=0)
param_data = param_data.drop(param_data.index[0])
print(param_data.tail())

labels = ['(0-5) years', '(6-10) years', '(11-18) years', '(19-70) years']
iloc_col = {  # (0-5)
    'IR': 6, 
    'EF': 10, 
    'ED': 14, 
    'BW': 18, 
    'AT': 22, 
    'DAIR': 35, 
    'VF': 47, 
    'SA': 68, 
    'F': 72, 
    'PC': 76, 
    'ET': 80, 
    
    'SF_o': 26, 
    'RfD_o': 30,
    'SF_i': 59, 
    'RfD_i': 63, 
    'SF_d': 100, 
    'RfD_d': 104, 
}

# 蒙特卡洛随机区间 (Monte Carlo random intervals)
exposure_data = pd.read_excel(os.path.join(file_root_dir, 'data', 'pollutant exposure parameters.xlsx'), index_col=0)
print(exposure_data.tail())

# 读取污染物浓度 (Read pollutant concentrations)
conc_name = 'Max_pollutant'
conc_data = pd.read_excel(os.path.join(file_root_dir, 'data', f'{conc_name}.xlsx'), index_col=0)
print(conc_data.tail())
# Out:
#              CAS                 Pollutants_name Abbreviation   污染物名称  Class  \
# No.
# 273.0   375-73-5   Perfluorobutane sulfonic acid         PFBS  全氟丁烷磺酸  PFSAs
# 274.0   355-46-4   Perfluorohexane sulfonic acid        PFHxS  全氟己烷磺酸  PFSAs
# 275.0   375-92-8  Perfluoroheptane sulfonic acid        PFHpS  全氟庚烷磺酸  PFSAs
# 276.0  1763-23-1   Perfluorooctane sulfonic acid         PFOS  全氟辛烷磺酸  PFSAs
# 277.0   335-77-3   Perfluorodecane sulfonic acid         PFDS  全氟癸烷磺酸  PFSAs
#
#         -    IR IR.1 IR.2 IR.3  ...  AT.10  AT.11  SFd SFd.1 SFd.2 SFd.3 RfDd  \
# No.                             ...
# 273.0 NaN  0.78    1  1.3    2  ...  25550  25550  NaN   NaN   NaN   NaN  NaN
# 274.0 NaN  0.78    1  1.3    2  ...  25550  25550  NaN   NaN   NaN   NaN  NaN
# 275.0 NaN  0.78    1  1.3    2  ...  25550  25550  NaN   NaN   NaN   NaN  NaN
# 276.0 NaN  0.78    1  1.3    2  ...  25550  25550  NaN   NaN   NaN   NaN  NaN
# 277.0 NaN  0.78    1  1.3    2  ...  25550  25550  NaN   NaN   NaN   NaN  NaN
#
#       RfDd.1 RfDd.2 RfDd.3
# No.
# 273.0    NaN    NaN    NaN
# 274.0    NaN    NaN    NaN
# 275.0    NaN    NaN    NaN
# 276.0    NaN    NaN    NaN
# 277.0    NaN    NaN    NaN
#
# [5 rows x 108 columns]
#                                                      Unit Distribution  \
# Parameters
# Volatile factor (VF)                                    /        Point
# Skin area (SA)                                        cm2   Log-normal
# Fraction of surface skin in contact with water (F)      -      Uniform
# Permeability constant (PC)                           cm/h        Point
# Exposure time (ET)                                  h/day   Log-normal
#
#                                                     (0-5) years_1  \
# Parameters
# Volatile factor (VF)                                        0.500
# Skin area (SA)                                           5838.000
# Fraction of surface skin in contact with water (F)          0.900
# Permeability constant (PC)                                  0.001
# Exposure time (ET)                                          0.770
#
#                                                     (0-5) years_2  \
# Parameters
# Volatile factor (VF)                                        0.500
# Skin area (SA)                                            920.000
# Fraction of surface skin in contact with water (F)          0.400
# Permeability constant (PC)                                  0.001
# Exposure time (ET)                                          0.790
#
#                                                     (6-10) years_1  \
# Parameters
# Volatile factor (VF)                                         0.500
# Skin area (SA)                                           10800.000
# Fraction of surface skin in contact with water (F)           0.900
# Permeability constant (PC)                                   0.001
# Exposure time (ET)                                           0.710
#
#                                                     (6-10) years_2  \
# Parameters
# Volatile factor (VF)                                         0.500
# Skin area (SA)                                            2486.000
# Fraction of surface skin in contact with water (F)           0.400
# Permeability constant (PC)                                   0.001
# Exposure time (ET)                                           0.740
#
#                                                     (11-18) years_1  \
# Parameters
# Volatile factor (VF)                                          0.500
# Skin area (SA)                                            17159.000
# Fraction of surface skin in contact with water (F)            0.900
# Permeability constant (PC)                                    0.001
# Exposure time (ET)                                            0.490
#
#                                                     (11-18) years_2  \
# Parameters
# Volatile factor (VF)                                          0.500
# Skin area (SA)                                             3199.000
# Fraction of surface skin in contact with water (F)            0.400
# Permeability constant (PC)                                    0.001
# Exposure time (ET)                                            0.580
#
#                                                     (19-70) years_1  \
# Parameters
# Volatile factor (VF)                                          0.500
# Skin area (SA)                                            16000.000
# Fraction of surface skin in contact with water (F)            0.900
# Permeability constant (PC)                                    0.001
# Exposure time (ET)                                            0.480
#
#                                                     (19-70) years_2
# Parameters
# Volatile factor (VF)                                          0.500
# Skin area (SA)                                              926.000
# Fraction of surface skin in contact with water (F)            0.400
# Permeability constant (PC)                                    0.001
# Exposure time (ET)                                            0.570
#                 CAS Pollutants_name Abbreviation  \
# Point
# CSNMWD30   375-73-5          全氟丁烷磺酸         PFBS
# CSNMWD30   355-46-4          全氟己烷磺酸        PFHxS
# CSNMWD30   375-92-8          全氟庚烷磺酸        PFHpS
# CSNMWD30  1763-23-1          全氟辛烷磺酸         PFOS
# CSNMWD30   335-77-3          全氟癸烷磺酸         PFDS
#
#                                    污染物名称  Class  Concentration(ug/L)
# Point
# CSNMWD30   Perfluorobutane sulfonic acid  PFSAs                  0.0
# CSNMWD30   Perfluorohexane sulfonic acid  PFSAs                  0.0
# CSNMWD30  Perfluoroheptane sulfonic acid  PFSAs                  0.0
# CSNMWD30   Perfluorooctane sulfonic acid  PFSAs                  0.0
# CSNMWD30   Perfluorodecane sulfonic acid  PFSAs                  0.0

# %%
from SALib.sample import sobol
from SALib.analyze import sobol as sobol_analyze
# 蒙特卡洛 样本数 (Monte Carlo sample size)
num_simulations = 10000

conc_len = len(conc_data.index)
print('conc_len: ', conc_len)

for idx in range(len(labels)):
    label = labels[idx]
    # # 蒙特卡洛 (Monte Carlo)
    IR_std, IR_mean = exposure_data.loc['GW ingestion rate (IR)', f'{label}_2'], exposure_data.loc['GW ingestion rate (IR)', f'{label}_1']
    IR = np.random.lognormal(IR_mean, IR_std, num_simulations)  # 水摄入率的对数正态分布（L/d） IR (Normal distribution of water intake rate (L/d) IR)
    EF = exposure_data.loc['Exposure frequency (EF)', f'{label}_2']   # 暴露频率（天/年）     EF (Exposure frequency (days/year) EF)
    ED_min, ED_max = exposure_data.loc['Exposure duration (ED)', f'{label}_2'], exposure_data.loc['Exposure duration (ED)', f'{label}_1'] 
    ED = np.random.uniform(ED_min, ED_max, num_simulations)  # 暴露持续时间（年）    ED (Exposure duration (years) ED)
    BW_std, BW_mean = exposure_data.loc['Body weight (BW)', f'{label}_2'], exposure_data.loc['Body weight (BW)', f'{label}_1']                 
    BW = np.random.normal(BW_mean, BW_std, num_simulations)  # 体重（kg） BW (Body weight (kg) BW)
    AT_C = exposure_data.loc['Averaging Time –Cancer risk', f'{label}_2']   # 致癌平均暴露时间     AT (Cancer risk averaging time AT)
    AT_NC = exposure_data.loc['Averaging Time - non cancer risk', f'{label}_2']   # 非致癌平均暴露时间     AT (Non-cancer risk averaging time AT)
    DAIR = exposure_data.loc['Daily air pulmonary ventilation rate (DAIR)', f'{label}_2']   # 每日空气肺通风率     DAIR (Daily air pulmonary ventilation rate DAIR)
    VF = exposure_data.loc['Volatile factor (VF)', f'{label}_2']   # 挥发性因子     VF (Volatile factor VF)
    SA_std, SA_mean = exposure_data.loc['Skin area (SA)', f'{label}_2'], exposure_data.loc['Skin area (SA)', f'{label}_1']
    SA = np.random.lognormal(SA_mean, SA_std, num_simulations)  # 皮肤暴露面积的对数正态分布（cm2）SA (Normal distribution of skin exposure area (cm2) SA)
    F_min, F_max = exposure_data.loc['Fraction of surface skin in contact with water (F)', f'{label}_2'], exposure_data.loc['Fraction of surface skin in contact with water (F)', f'{label}_1']
    F = np.random.uniform(F_min, F_max, num_simulations)  # 与水接触的表面皮肤的比例  F (Proportion of surface skin in contact with water F)
    PC = exposure_data.loc['Permeability constant (PC)', f'{label}_2']   # 皮肤渗透系数（cm/h） PC (Skin permeability constant (cm/h) PC)
    ET_std, ET_mean = exposure_data.loc['Exposure time (ET)', f'{label}_2'], exposure_data.loc['Exposure time (ET)', f'{label}_1']
    ET = np.random.lognormal(ET_mean, ET_std, num_simulations)  # 皮肤暴露时间（h/day） ET (Skin exposure time (h/day) ET)
    
    # 写入CSV文件头 (Write CSV file headers)
    write_csv(file_path=f'./{label}_CR_oral_ingestion.csv', rowdata=[
        "cas", "C_i_S1", "IR_S1", "ED_S1", "BW_S1", "SA_S1", "F_S1", "ET_S1", "C_i_ST", "IR_ST", "ED_ST", "BW_ST", "SA_ST", "F_ST", "ET_ST"])
    write_csv(file_path=f'./{label}_CR_dermal.csv', rowdata=[
        "cas", "C_i_S1", "IR_S1", "ED_S1", "BW_S1", "SA_S1", "F_S1", "ET_S1", "C_i_ST", "IR_ST", "ED_ST", "BW_ST", "SA_ST", "F_ST", "ET_ST"])
    write_csv(file_path=f'./{label}_CR_inhalation.csv', rowdata=[
        "cas", "C_i_S1", "IR_S1", "ED_S1", "BW_S1", "SA_S1", "F_S1", "ET_S1", "C_i_ST", "IR_ST", "ED_ST", "BW_ST", "SA_ST", "F_ST", "ET_ST"])
    write_csv(file_path=f'./{label}_HQ_oral_ingestion.csv', rowdata=[
        "cas", "C_i_S1", "IR_S1", "ED_S1", "BW_S1", "SA_S1", "F_S1", "ET_S1", "C_i_ST", "IR_ST", "ED_ST", "BW_ST", "SA_ST", "F_ST", "ET_ST"])
    write_csv(file_path=f'./{label}_HQ_dermal.csv', rowdata=[
        "cas", "C_i_S1", "IR_S1", "ED_S1", "BW_S1", "SA_S1", "F_S1", "ET_S1", "C_i_ST", "IR_ST", "ED_ST", "BW_ST", "SA_ST", "F_ST", "ET_ST"])
    write_csv(file_path=f'./{label}_HQ_inhalation.csv', rowdata=[
        "cas", "C_i_S1", "IR_S1", "ED_S1", "BW_S1", "SA_S1", "F_S1", "ET_S1", "C_i_ST", "IR_ST", "ED_ST", "BW_ST", "SA_ST", "F_ST", "ET_ST"])
    
    for conc_th in range(conc_len):
        pollutant_name = conc_data.iloc[conc_th, 0]
        print(f'{label}-{conc_th}-{pollutant_name}')
        
        C_i = conc_data.loc[:, 'Concentration(ug/L)'].values[conc_th]
        # 正态:  mean,  sd (Normal: mean, sd)
        # 均匀:  min,   max (Uniform: min, max)
        problem = {
            "num_vars": 7,
            "names": ["C_i", "IR", "ED", "BW", "SA", "F", "ET"],
            "bounds": [
                [C_i * 0.8, C_i * 1.2 + 1e-6], 
                [IR_mean, IR_std], 
                [ED_min, ED_max],  
                [BW_mean, BW_std], 
                [SA_mean, SA_std], 
                [F_min, F_max], 
                [ET_mean, ET_std]
            ],
            "dists": [   
                "unif",  # 浓度 (Concentration)
                "norm",  # 水摄入率 (Water intake rate)
                "unif",  # 暴露持续时间 (Exposure duration)
                "norm",  # 体重 (Body weight)
                "norm",  # 皮肤面积 (Skin area)
                "unif",  # 皮肤接触比例 (Skin contact fraction)
                "norm",  # 暴露时间 (Exposure time)
            ],
        }
        print(problem)
        X = sobol.sample(problem, num_simulations, calc_second_order=False)
        C_i_simulation, IR, ED, BW, SA, F, ET = X[:, 0], X[:, 1], X[:, 2], X[:, 3], X[:, 4], X[:, 5], X[:, 6]  # (9*num_simulations, )
        # # 剂量计算 (Dose calculation)
        
        # 口服摄入剂量 (Oral ingestion dose)
        add_oral_ingestion_C = cal_add_oral_ingestion(
            C_i=C_i_simulation, 
            IR=IR, 
            EF=EF, 
            ED=EF, 
            BW=BW, 
            AT=AT_C, 
        )
        add_oral_ingestion_NC = cal_add_oral_ingestion(
            C_i=C_i_simulation, 
            IR=IR, 
            EF=EF, 
            ED=EF, 
            BW=BW, 
            AT=AT_NC, 
        )
        
        # 皮肤接触剂量 (Dermal contact dose)
        add_dermal_C = cal_add_dermal(
            C_i=C_i_simulation, 
            SA=SA, 
            F=F, 
            PC=PC, 
            ET=ET, 
            EF=EF, 
            ED=ED, 
            BW=BW, 
            AT=AT_C, 
        )
        
        add_dermal_NC = cal_add_dermal(
            C_i=C_i_simulation, 
            SA=SA, 
            F=F, 
            PC=PC, 
            ET=ET, 
            EF=EF, 
            ED=ED, 
            BW=BW, 
            AT=AT_NC, 
        )
        
        # 吸入剂量 (Inhalation dose)
        add_inhalation_C = cal_add_inhalation(
            C_i=C_i_simulation, 
            DAIR=DAIR, 
            EF=EF, 
            ED=ED, 
            VF=VF, 
            BW=BW, 
            AT=AT_C, 
        )
        
        add_inhalation_NC = cal_add_inhalation(
            C_i=C_i_simulation, 
            DAIR=DAIR, 
            EF=EF, 
            ED=ED, 
            VF=VF, 
            BW=BW, 
            AT=AT_C, 
        )
        
        # 致癌 风险 (Cancer risk)
        CR_oral_ingestion_C = cal_CR(add=add_oral_ingestion_C, SF=np.array([1.0]))
        CR_dermal_C = cal_CR(add=add_dermal_C, SF=np.array([1.0]))
        CR_inhalation_C = cal_CR(add=add_inhalation_C, SF=np.array([1.0]))
        # 非致癌 风险 (Non-cancer risk)
        HQ_oral_ingestion_NC = cal_hq(add=add_oral_ingestion_NC, RfD=np.array([1.0]))
        HQ_dermal_C_NC = cal_hq(add=add_dermal_NC, RfD=np.array([1.0]))
        HQ_inhalation_NC = cal_hq(add=add_inhalation_NC, RfD=np.array([1.0]))
        
        # 敏感性分析 (Sensitivity analysis)
        CR_oral_ingestion_C_Si = sobol_analyze.analyze(problem,
                           CR_oral_ingestion_C,
                           calc_second_order=False,
                           print_to_console=False)
        CR_dermal_C_Si = sobol_analyze.analyze(problem,
                           CR_dermal_C,
                           calc_second_order=False,
                           print_to_console=False)
        CR_inhalation_C_Si = sobol_analyze.analyze(problem,
                           CR_inhalation_C,
                           calc_second_order=False,
                           print_to_console=False)
        HQ_oral_ingestion_NC_Si = sobol_analyze.analyze(problem,
                           HQ_oral_ingestion_NC,
                           calc_second_order=False,
                           print_to_console=False)
        HQ_dermal_C_NC_Si = sobol_analyze.analyze(problem,
                           HQ_dermal_C_NC,
                           calc_second_order=False,
                           print_to_console=False)
        HQ_inhalation_NC_Si = sobol_analyze.analyze(problem,
                           HQ_inhalation_NC,
                           calc_second_order=False,
                           print_to_console=False)
        # "C_i", "IR", "ED", "BW", "SA", "F", "ET"
        # 写入敏感性分析结果 (Write sensitivity analysis results)
        write_csv(file_path=f'./{label}_CR_oral_ingestion.csv', rowdata=np.concatenate([[pollutant_name], CR_oral_ingestion_C_Si["S1"], CR_oral_ingestion_C_Si['ST']], axis=0))
        write_csv(file_path=f'./{label}_CR_dermal.csv', rowdata=np.concatenate([[pollutant_name], CR_dermal_C_Si["S1"], CR_dermal_C_Si['ST']], axis=0))
        write_csv(file_path=f'./{label}_CR_inhalation.csv', rowdata=np.concatenate([[pollutant_name], CR_inhalation_C_Si["S1"], CR_inhalation_C_Si['ST']], axis=0))
        write_csv(file_path=f'./{label}_HQ_oral_ingestion.csv', rowdata=np.concatenate([[pollutant_name], HQ_oral_ingestion_NC_Si["S1"], HQ_oral_ingestion_NC_Si['ST']], axis=0))
        write_csv(file_path=f'./{label}_HQ_dermal.csv', rowdata=np.concatenate([[pollutant_name], HQ_dermal_C_NC_Si["S1"], HQ_dermal_C_NC_Si['ST']], axis=0))
        write_csv(file_path=f'./{label}_HQ_inhalation.csv', rowdata=np.concatenate([[pollutant_name], HQ_inhalation_NC_Si["S1"], HQ_inhalation_NC_Si['ST']], axis=0))
# Out:
# conc_len:  277
# (0-5) years-0-7664-41-7
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(349600.0), np.float64(524400.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# C:\Users\1\AppData\Roaming\Python\Python39\site-packages\scipy\stats\_qmc.py:958: UserWarning: The balance properties of Sobol' points require n to be a power of 2.
#   sample = self._random(n, workers=workers)
# C:\Users\1\AppData\Roaming\Python\Python39\site-packages\SALib\util\__init__.py:274: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   names = list(pd.unique(groups))
# (0-5) years-1-14797-55-8
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(568800.0), np.float64(853200.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-2-14797-65-0
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(40480.0), np.float64(60720.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-3-14808-79-8
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(7704000.0), np.float64(11556000.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-4-18496-25-8
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(25520.0), np.float64(38280.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-5-16984-48-8
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(35280.0), np.float64(52920.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-6-16887-00-6
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(7656000.0), np.float64(11484000.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-7-20461-54-5
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(15040.0), np.float64(22560.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-8-57-12-5
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(166.4), np.float64(249.600001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-9-7440-23-5
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(11120000.0), np.float64(16680000.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-10-7429-90-5
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(16960.0), np.float64(25440.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-11-7439-89-6
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(257600.0), np.float64(386400.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-12-7439-92-1
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(428.0), np.float64(642.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-13-7439-96-5
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(90400.0), np.float64(135600.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-14-7439-97-6
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(4.984000000000001), np.float64(7.476001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-15-7439-98-7
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(155.20000000000002), np.float64(232.80000099999998)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-16-7440-02-0
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(4392.0), np.float64(6588.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-17-7440-22-4
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(1.168), np.float64(1.752001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-18-7440-28-0
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-19-7440-31-5
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(164.8), np.float64(247.200001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-20-7440-32-6
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-21-7440-36-0
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(36.52), np.float64(54.78000099999999)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-22-7440-38-2
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(3712.0), np.float64(5568.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-23-7440-39-3
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(28960.0), np.float64(43440.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-24-7440-41-7
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(108.80000000000001), np.float64(163.200001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-25-7440-42-8
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-26-7440-43-9
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(15.12), np.float64(22.680000999999997)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-27-7440-47-3
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(36.0), np.float64(54.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-28-7440-48-4
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(93.376), np.float64(140.064001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-29-7440-50-8
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(268.0), np.float64(402.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-30-7440-62-2
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(52.96000000000001), np.float64(79.440001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-31-7440-66-6
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(44080.0), np.float64(66120.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-32-7782-49-2
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(73.36), np.float64(110.040001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-33-127-18-4
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(31.680000000000003), np.float64(47.520001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-34-75-09-2
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(42548.08), np.float64(63822.120000999996)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-35-67-66-3
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(224800.0), np.float64(337200.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-36-107-06-2
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(158359.55200000003), np.float64(237539.328001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-37-79-01-6
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(60.785590024), np.float64(91.17838603599999)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-38-56-23-5
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(7.2), np.float64(10.800000999999998)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-39-75-01-4
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(166927.2), np.float64(250390.800001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-40-75-35-4
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(9858.080000000002), np.float64(14787.120001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-41-71-55-6
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(45.04), np.float64(67.56000099999999)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-42-79-00-5
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(48240.48), np.float64(72360.720001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-43-87-68-3
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-44-75-25-2
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-45-540-59-0
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(3504.0), np.float64(5256.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-46-79-34-5
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-47-78-87-5
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(98.99240672), np.float64(148.48861108)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-48-75-34-3
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(1124.72), np.float64(1687.0800010000003)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-49-74-83-9
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-50-75-00-3
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-51-124-48-1
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-52-156-60-5
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(10.193840000000002), np.float64(15.290760999999998)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-53-74-87-3
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(180.8), np.float64(271.200001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-54-106-93-4
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(64.56), np.float64(96.840001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-55-10061-01-5
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-56-67-72-1
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(3.0480212776), np.float64(4.5720329163999995)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-57-96-18-4
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(2472.0), np.float64(3708.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-58-7005-72-3
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-59-75-69-4
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-60-75-71-8
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-61-75-27-4
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(154.59424), np.float64(231.89136099999996)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-62-630-20-6
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(1581.8202248), np.float64(2372.7303381999996)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-63-563-58-6
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-64-95-94-3
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(3.04), np.float64(4.560001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-65-96-12-8
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-66-142-28-9
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(3728.0), np.float64(5592.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-67-594-20-7
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(5.120000000000001), np.float64(7.680001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-68-321-60-8
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(102.4), np.float64(153.600001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-69-95-49-8
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(1496.0), np.float64(2244.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-70-91-58-7
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-71-106-43-4
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(1344.0), np.float64(2016.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-72-1868-53-7
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(100.80000000000001), np.float64(151.200001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-73-74-95-3
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-74-1888-71-7
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(29.04), np.float64(43.56000099999999)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-75-10061-02-6
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-76-74-97-5
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-77-156-59-2
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-78-191-24-2
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(2.6775194664), np.float64(4.0162801996)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-79-50-32-8
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(2.6721601360000005), np.float64(4.008241204)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-80-91-20-3
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(429.6), np.float64(644.400001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-81-205-99-2
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(30.32), np.float64(45.480000999999994)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-82-206-44-0
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(12.08), np.float64(18.120001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-83-207-08-9
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(1.4712251424), np.float64(2.2068387136)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-84-120-12-7
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(6.112), np.float64(9.168000999999999)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-85-193-39-5
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(2.415126588), np.float64(3.622690882)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-86-218-01-9
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(2.144), np.float64(3.2160010000000003)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-87-53-70-3
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.752), np.float64(1.1280009999999998)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-88-56-55-3
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-89-129-00-0
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(8.72), np.float64(13.080001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-90-83-32-9
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(1072.0), np.float64(1608.000001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-91-85-01-8
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(60.96000000000001), np.float64(91.440001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-92-208-96-8
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.4112), np.float64(0.616801)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-93-86-73-7
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.8940347248), np.float64(1.3410530872)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-94-91-57-6
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(1.6), np.float64(2.400001)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-95-132-64-9
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(1.2800000000000002), np.float64(1.9200009999999998)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-96-60-51-5
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-97-62-73-7
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-98-298-00-0
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-99-56-38-2
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-100-2921-88-2
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-101-121-75-5
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-102-1071-83-6
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-103-1563-66-2
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-104-1897-45-6
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-105-1912-24-9
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-106-1610-17-9
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-107-52-68-6
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-108-1582-09-8
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-109-116-06-3
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-110-51218-45-2
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-111-15972-60-8
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-112-1836-75-5
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-113-55-38-9
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-114-470-90-6
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-115-319-84-6
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-116-319-85-7
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-117-319-86-8
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-118-50-29-3
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-119-58-89-9
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(4.8162320352000005), np.float64(7.2243490528)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-120-94-75-7
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-121-76-44-8
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# (0-5) years-122-309-00-2
# {'num_vars': 7, 'names': ['C_i', 'IR', 'ED', 'BW', 'SA', 'F', 'ET'], 'bounds': [[np.float64(0.0), np.float64(1e-06)], [np.float64(0.65), np.float64(0.39)], [np.float64(0.0), np.float64(5.0)], [np.float64(16.68), np.float64(1.48)], [np.float64(5838.0), np.float64(920.0)], [np.float64(0.4), np.float64(0.9)], [np.float64(0.77), np.float64(0.79)]], 'dists': ['unif', 'norm', 'unif', 'norm', 'norm', 'unif', 'norm']}
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14008\2082270102.py in <module>
#     177                            print_to_console=False)
#     178         # "C_i", "IR", "ED", "BW", "SA", "F", "ET"
# --> 179         write_csv(file_path=f'./{label}_CR_oral_ingestion.xlsx', rowdata=np.concatenate([[pollutant_name], CR_oral_ingestion_C_Si["S1"], CR_oral_ingestion_C_Si['ST']], axis=0))
#     180         write_csv(file_path=f'./{label}_CR_dermal.xlsx', rowdata=np.concatenate([[pollutant_name], CR_dermal_C_Si["S1"], CR_dermal_C_Si['ST']], axis=0))
#     181         write_csv(file_path=f'./{label}_CR_inhalation.xlsx', rowdata=np.concatenate([[pollutant_name], CR_inhalation_C_Si["S1"], CR_inhalation_C_Si['ST']], axis=0))
#
# ~\AppData\Local\Temp\ipykernel_14008\3684230287.py in write_csv(file_path, rowdata)
#      27
#      28 def write_csv(file_path='./write.csv', rowdata=[]):
# ---> 29     with open(file_path, 'a') as f:
#      30         f.write(','.join([f"{data:.9f}" if isinstance(data, float) else str(data) for data in rowdata]))
#      31         f.write('\n')
#
# PermissionError: [Errno 13] Permission denied: './(0-5) years_CR_oral_ingestion.xlsx'
